# %%
from manim import *
from manim.opengl import *
from model.default_conc import MISFOLDED_CONC, HEALTHY_CONC, LINSPACE

sol_fk_1 = MISFOLDED_CONC

# %%
# %%manim -pql ConcentrationProgression_FK1
#
# class ConcentrationProgression_FK1(Scene):
#     # def __init__(self, sol_y=None, **kwargs):
#     #     super().__init__(**kwargs)
#     #     self.sol_y = sol_y if sol_y else []  # Use the passed sol_y or initialize as empty list
#
#     def construct(self):
#         # Step 1: Display the text "Fisher Kolmogorov Model"
#         title = Text("Fisher-Kolmogorov Model")
#         self.play(Write(title))
#
#         # Step 2: Move the text upwards
#         self.play(title.animate.shift(UP))
#         self.wait(0.5)
#
#         # Step 3: Display the mathematical equation in LaTeX
#         model_equation = MathTex(
#             r"\frac{dc_1}{dt} = - \sum_{j=1}^{N} L_{ij} c_j + \alpha c_1 (1 - c_1)"
#         )
#         self.play(Write(model_equation))
#         self.wait(2)
#
#         # Step 4: Remove current objects
#         self.play(FadeOut(title), FadeOut(model_equation))
#
#         # Step 5: New title
#         updated_title = Text("Fisher-Kolmogorov Model - 1 Node")
#         self.play(Write(updated_title))
#         self.play(updated_title.animate.shift(UP * 2))
#         self.wait(1)
#
#         # Step 6: Display the graph Laplacian for a single node
#         laplacian_matrix = MathTex(
#             r"L = \begin{pmatrix} 0 \end{pmatrix}"
#         )
#         self.play(Write(laplacian_matrix))
#         self.wait(1)
#
#         # Step 7: Remove graph Laplacian matrix
#         self.remove(laplacian_matrix)
#         self.wait(0.5)
#
#         # Step 8: Display the equation for N = 1
#         equation_n1 = MathTex(
#             r"\frac{dc_1}{dt} = \alpha c_1 (1 - c_1)"
#         )
#         self.play(Write(equation_n1))
#         self.wait(2)
#
#         # Step 9: Position title and equation
#         self.play(
#             updated_title.animate.scale(0.8).to_edge(UP),
#             equation_n1.animate.scale(0.8).to_edge(DOWN)
#         )
#         self.wait(2)
#
#
#         # Step 10: Create a circle
#         circle = Circle(radius=2, color=WHITE, stroke_width=0)
#         circle.set_fill(WHITE, opacity=1)  # Ensure the initial color is filled
#         self.add(circle)
#         global sol_fk_1
#         global LINSPACE
#
#         # Step 11: Add time display
#         time_display = DecimalNumber(0, num_decimal_places=1, color=WHITE)
#         time_display.next_to(circle, DOWN)  # Position below the circle
#         self.add(time_display)
#
#         # Step 12: Animate color changes and time updates
#         for concentration, time in zip(sol_fk_1, LINSPACE):
#             # Calculate the new color based on the concentration
#             new_color = interpolate_color(WHITE, PURE_RED, concentration)
#
#             # Update time display
#             self.play(
#                 circle.animate.set_fill(new_color, opacity=1),
#                 time_display.animate.set_value(time),
#                 run_time=0.5  # Duration for each step
#             )
#             self.wait(0.1)
#
#         # Wait at the end
#         self.wait(2)
# Out:
# Manim Community v0.18.1
# [01/10/25 12:25:15] INFO     Animation 0 : Using cached data (hash :                           ]8;id=523215;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=567039;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              1185818338_220545559_223132457)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=955986;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=867685;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_858151922_2374243091)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=604332;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=776102;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_1959358871_503584236)
# [01/10/25 12:25:16] INFO     Animation 3 : Using cached data (hash :                           ]8;id=48595;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=433160;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_19371044_3846434980)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=149629;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=463854;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_1141282389_214803386)
# [01/10/25 12:25:17] INFO     Animation 5 : Using cached data (hash :                           ]8;id=294220;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=334212;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_2686440742_3420935660)
#                     INFO     Animation 6 : Using cached data (hash :                           ]8;id=623249;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=897513;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_3125255687_758497372)
# [01/10/25 12:25:18] INFO     Animation 7 : Using cached data (hash :                           ]8;id=566539;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=99766;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_3200929386_1119546803)
#                     INFO     Animation 8 : Using cached data (hash :                           ]8;id=478469;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=415917;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_3890345977_66439292)
# [01/10/25 12:25:19] INFO     Animation 9 : Using cached data (hash :                           ]8;id=986905;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=266711;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_2491019058_175334584)
#                     INFO     Animation 10 : Using cached data (hash :                          ]8;id=557662;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=900757;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_3890345977_4167448263)
#                     INFO     Animation 11 : Using cached data (hash :                          ]8;id=941704;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=295189;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_1959358871_3294753214)
# [01/10/25 12:25:20] INFO     Animation 12 : Using cached data (hash :                          ]8;id=800731;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=536300;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_3744625735_854462672)
#                     INFO     Animation 13 : Using cached data (hash :                          ]8;id=845466;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=933704;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_1141282389_2627368618)
# [01/10/25 12:25:21] INFO     Animation 14 : Using cached data (hash :                          ]8;id=702050;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=585938;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_2825279772_910031672)
#                     INFO     Animation 15 : Using cached data (hash :                          ]8;id=342704;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=777350;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\renderer\cairo_renderer.py#88\88]8;;\
#                              624642324_1141282389_2108580857)
#                     INFO     Writing 0 to media\Tex\66e1bc57a83e0f07.tex                    ]8;id=620397;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=413137;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\utils\tex_file_writing.py#109\109]8;;\
# [01/10/25 12:25:27] INFO     Writing . to media\Tex\ec2b01090b1fbb55.tex                    ]8;id=908090;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\utils\tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=353793;file://C:\Users\sranasin\AppData\Roaming\Python\Python312\site-packages\manim\utils\tex_file_writing.py#109\109]8;;\
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 get_ipython().run_cell_magic('manim', '-pql ConcentrationProgression_FK1', '\nclass ConcentrationProgression_FK1(Scene):\n    # def __init__(self, sol_y=None, **kwargs):\n    #     super().__init__(**kwargs)\n    #     self.sol_y = sol_y if sol_y else []  # Use the passed sol_y or initialize as empty list\n\n    def construct(self):\n        # Step 1: Display the text "Fisher Kolmogorov Model"\n        title = Text("Fisher-Kolmogorov Model")\n        self.play(Write(title))\n\n        # Step 2: Move the text upwards\n        self.play(title.animate.shift(UP))\n        self.wait(0.5)\n\n        # Step 3: Display the mathematical equation in LaTeX\n        model_equation = MathTex(\n            r"\\frac{dc_1}{dt} = - \\sum_{j=1}^{N} L_{ij} c_j + \\alpha c_1 (1 - c_1)"\n        )\n        self.play(Write(model_equation))\n        self.wait(2)\n        \n        # Step 4: Remove current objects\n        self.play(FadeOut(title), FadeOut(model_equation))\n        \n        # Step 5: New title\n        updated_title = Text("Fisher-Kolmogorov Model - 1 Node")\n        self.play(Write(updated_title))\n        self.play(updated_title.animate.shift(UP * 2))\n        self.wait(1)\n\n        # Step 6: Display the graph Laplacian for a single node\n        laplacian_matrix = MathTex(\n            r"L = \\begin{pmatrix} 0 \\end{pmatrix}"\n        )\n        self.play(Write(laplacian_matrix))\n        self.wait(1)\n\n        # Step 7: Remove graph Laplacian matrix\n        self.remove(laplacian_matrix)\n        self.wait(0.5)\n\n        # Step 8: Display the equation for N = 1\n        equation_n1 = MathTex(\n            r"\\frac{dc_1}{dt} = \\alpha c_1 (1 - c_1)"\n        )\n        self.play(Write(equation_n1))\n        self.wait(2)\n\n        # Step 9: Position title and equation\n        self.play(\n            updated_title.animate.scale(0.8).to_edge(UP),\n            equation_n1.animate.scale(0.8).to_edge(DOWN)\n        )\n        self.wait(2)\n\n        \n        # Step 10: Create a circle\n        circle = Circle(radius=2, color=WHITE, stroke_width=0)\n        circle.set_fill(WHITE, opacity=1)  # Ensure the initial color is filled\n        self.add(circle)\n        global sol_fk_1\n        global LINSPACE\n        \n        # Step 11: Add time display\n        time_display = DecimalNumber(0, num_decimal_places=1, color=WHITE)\n        time_display.next_to(circle, DOWN)  # Position below the circle\n        self.add(time_display)\n\n        # Step 12: Animate color changes and time updates\n        for concentration, time in zip(sol_fk_1, LINSPACE):\n            # Calculate the new color based on the concentration\n            new_color = interpolate_color(WHITE, PURE_RED, concentration)\n            \n            # Update time display\n            self.play(\n                circle.animate.set_fill(new_color, opacity=1),\n                time_display.animate.set_value(time),\n                run_time=0.5  # Duration for each step\n            )\n            self.wait(0.1)\n\n        # Wait at the end\n        self.wait(2)\n')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\manim\utils\ipython_magic.py:143, in ManimMagic.manim(self, line, cell, local_ns)
#     141     SceneClass = local_ns[config["scene_names"][0]]
#     142     scene = SceneClass(renderer=renderer)
# --> 143     scene.render()
#     144 finally:
#     145     # Shader cache becomes invalid as the context is destroyed
#     146     shader_program_cache.clear()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\manim\scene\scene.py:229, in Scene.render(self, preview)
#     227 self.setup()
#     228 try:
# --> 229     self.construct()
#     230 except EndSceneEarlyException:
#     231     pass
#
# File <string>:71, in construct(self)
#
# NameError: name 'LINSPACE' is not defined
